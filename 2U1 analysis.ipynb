# %%
from fasta import *
import alignment
import utilities
from checkGenome import *
from ipywidgets import widgets
from ipywidgets import *
from traitlets import *
from IPython.display import display

# %% [markdown]
# # Loading the files
#
# The first thing we want to do is load in our files. Loading them in this way actually loads them into a dictionary where the keys are the record IDs and the values are the full records.

# %%
# Load the 2U1 files
records_with_40_identity = SeqIO.to_dict(SeqIO.parse("/Users/gabefoley/Dropbox/PhD/Projects/2U1/2U1_2018/BLAST_unique.fasta", "fasta"))

records_with_55_identity =

# %% [markdown]
# #### How many sequences do we have in the full records?

# %%
print (len(full_record))
# Out:
# 17180

# %% [markdown]
# # Creating subsets of the records
# ### Including / excluding based on header annotations
#
# Now the workflow moves to including and excluding certain sequences. `subset_records` allows us to provide a list of terms which we either want or don't want in the header description. We can also give a minimum length for sequences to meet for inclusion.
#
# We don't ever alter the original `full_record`, we just create new dictionary objects that are subsets.
#
# We can either provide arguments directly to the function or we can pass in a list variable, such as `header_terms`.
#
# In the example below `only_2U1_records` is set to only include sequences which have either '2U1' or '2U1-like' in the header. And `filtered_records` will contain the full set of sequences as we are not providing a length minimum (and the default is 0) and we are passing in the currently empty `header_terms`.

# %%
# A blank list to hold terms we want to exclude or include
header_terms = []

# %%
only_2U1_records = subset_records("2U1", "2U1-like", records=full_record, length=400, mode="include")
filtered_records = subset_records(*header_terms, records=full_record, length=400, mode='exclude')
x_removed_records = exclude_character(filtered_records, "X")

print ("The number of sequences with either 2U1 or 2U1-like in the header is %s " % (len(only_2U1_records)))
print ("The number of sequences we've filtered is %s which should be equal to %s" % (len(filtered_records), len(full_record)))
print ("The number of sequences without X character is %s" % (len(x_removed_records)))
# Out:
# The number of sequences with either 2U1 or 2U1-like in the header is 439
# The number of sequences we've filtered is 14024 which should be equal to 17180
# The number of sequences without X character is 13296

# %%
test_records = subset_records_with_regex("\[Mycobacterium", "93A", "78A", "76A", "71D", "21-hydroxylase","17-alpha-hydroxylase","25-hydroxylase","subfamily A", "subfamily a","subfamily 2 J19", "Cyp2c38", "subfamily D", "subfamily d", "subfamily E", "subfamily e", "subfamily AA", "subfamily C", "subfamily X", "subfamily x", "subfamily c", "subfamily J", "subfamily j", "subfamily AD", "subfamily ad", "subfamily B", "subfamily b", "subfamily k", "subfamily K", "2D", "2J", "2B", "2A", "2B", "2C", "2D", "2E", "2F", "2G", "2H", "2I", "2J", "2K", "2L", "2M", "2N", "2O", "2P", "2Q", "2R", "2S", "2T", "2V", "2W", "2X", "2Y", "2Z", "1A", "1B", "76C", "84A", "98A", "304a1", "305a1", "306a1", "CYP17A", "303a1", "307a1", "83B", "81E", "81d1", "81D1", "18", "4X", "26", "A6", "303", "CYP3", "CYP1", "CYP4", "2h" "CYP5", "CYP6", "CYP7", "CYP8", "B9", "Cyp3", "Cyp1", "Cyp4", "Cyp5", "Cyp6", "Cyp7", "Cyp8", "25-hy", "3A", "4V", "Cyp2c", "Cyp2x", "2b4", "Cyp2a", "subfamily t", "subfamily b", "4B1", "A 37", "4a", "4A", "4F", "leukotriene-B4", "4g", "4d", "4C", "4c", "P450c", "Methyl farnesoate epoxidase", "4Z", "subfamily f", "subfamily V", "subfamily R", "2d", "Cyp2r", "subfamily r", "subfamily N", "subfamily P", "subfamily R", "2b", "Cyp2f", "family 17", "17A", "17alpha", "17a", "subfamily S", "32", "cyp17", "1C1", "methyl farnesoate", "27C1",          records=x_removed_records, mode="exclude")
# test_records = subset_records_with_regex("2U", records=full_record, mode="include")
# test_records = subset_records("uncharacterized", "25-hydroxylase", "partial", "hypothetical", "unnamed", "Cyp2r1", records=test_records, mode='exclude')

print (len(test_records))
# Out:
# 1981

# %%
for item in test_records:
    print (test_records[item].description)
# Out:
# XP_014796211.1 PREDICTED: cytochrome P450 2U1 [Calidris pugnax]
# XP_010584537.1 PREDICTED: cytochrome P450 2U1, partial [Haliaeetus leucocephalus]
# XP_017688993.1 PREDICTED: cytochrome P450 2U1 [Lepidothrix coronata]
# XP_011572877.1 PREDICTED: cytochrome P450 2U1 [Aquila chrysaetos canadensis]
# XP_021381195.1 cytochrome P450 2U1 [Lonchura striata domestica]
# XP_005484794.1 PREDICTED: cytochrome P450 2U1 [Zonotrichia albicollis]
# XP_005044990.1 PREDICTED: cytochrome P450 2U1, partial [Ficedula albicollis]
# XP_002194737.2 PREDICTED: cytochrome P450 2U1 [Taeniopygia guttata]
# XP_009099794.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Serinus canaria]
# XP_014733783.1 PREDICTED: cytochrome P450 2U1 [Sturnus vulgaris]
# XP_015480586.1 PREDICTED: cytochrome P450 2U1 [Parus major]
# XP_021251581.1 cytochrome P450 2U1 [Numida meleagris]
# XP_015716841.1 PREDICTED: cytochrome P450 2U1 [Coturnix japonica]
# XP_420491.3 PREDICTED: cytochrome P450 2U1 [Gallus gallus]
# KFO79198.1 Cytochrome P450 2U1, partial [Cuculus canorus]
# XP_009563306.1 PREDICTED: cytochrome P450 2U1 [Cuculus canorus]
# KFV68671.1 Cytochrome P450 2U1, partial [Picoides pubescens]
# XP_009900551.1 PREDICTED: cytochrome P450 2U1, partial [Picoides pubescens]
# XP_010077161.1 PREDICTED: LOW QUALITY PROTEIN: cytochrome P450 2U1, partial [Pterocles gutturalis]
# XP_005148751.1 PREDICTED: cytochrome P450 2U1, partial [Melopsittacus undulatus]
# OPJ75701.1 cytochrome P450 2U1 [Patagioenas fasciata monilis]
# KFW75712.1 Cytochrome P450 2U1, partial [Manacus vitellinus]
# OWK57154.1 Cytochrome P450 2U1 [Lonchura striata domestica]
# XP_010224405.1 PREDICTED: cytochrome P450 2U1 [Tinamus guttatus]
# XP_017928159.1 PREDICTED: cytochrome P450 2U1 [Manacus vitellinus]
# XP_010410415.1 cytochrome P450 2U1, partial [Corvus cornix cornix]
# KGL85110.1 Cytochrome P450 2U1, partial [Tinamus guttatus]
# XP_005515313.3 cytochrome P450 2U1 [Columba livia]
# XP_005287999.1 PREDICTED: cytochrome P450 2U1 [Chrysemys picta bellii]
# XP_010008547.1 PREDICTED: cytochrome P450 2U1-like [Nestor notabilis]
# XP_009647457.1 PREDICTED: cytochrome P450 2U1 [Egretta garzetta]
# XP_009919298.1 PREDICTED: cytochrome P450 2U1, partial [Haliaeetus albicilla]
# XP_009930453.1 PREDICTED: cytochrome P450 2U1 [Opisthocomus hoazin]
# XP_009883824.1 PREDICTED: cytochrome P450 2U1 [Charadrius vociferus]
# XP_014427106.1 PREDICTED: cytochrome P450 2U1 [Pelodiscus sinensis]
# XP_019377492.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Gavialis gangeticus]
# XP_006272957.2 PREDICTED: cytochrome P450 2U1 isoform X1 [Alligator mississippiensis]
# OXB76790.1 hypothetical protein H355_016271 [Colinus virginianus]
# XP_020652021.1 cytochrome P450 2U1, partial [Pogona vitticeps]
# OXB68583.1 hypothetical protein ASZ78_014362 [Callipepla squamata]
# XP_006031203.1 PREDICTED: cytochrome P450 2U1 [Alligator sinensis]
# XP_015281737.1 PREDICTED: cytochrome P450 2U1 [Gekko japonicus]
# XP_007054542.1 PREDICTED: cytochrome P450 2U1-like [Chelonia mydas]
# XP_006727242.1 PREDICTED: cytochrome P450 2U1-like [Leptonychotes weddellii]
# XP_019684690.2 cytochrome P450 2U1 isoform X1 [Felis catus]
# XP_019272345.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Panthera pardus]
# XP_006869388.1 PREDICTED: cytochrome P450 2U1-like [Chrysochloris asiatica]
# XP_015665994.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Protobothrops mucrosquamatus]
# EFB16740.1 hypothetical protein PANDA_005136, partial [Ailuropoda melanoleuca]
# XP_004411289.1 PREDICTED: cytochrome P450 2U1 [Odobenus rosmarus divergens]
# XP_022370877.1 cytochrome P450 2U1 [Enhydra lutris kenyoni]
# XP_006881166.1 PREDICTED: cytochrome P450 2U1-like [Elephantulus edwardii]
# XP_004748170.1 PREDICTED: cytochrome P450 2U1 [Mustela putorius furo]
# XP_006162319.2 PREDICTED: cytochrome P450 2U1 [Tupaia chinensis]
# XP_003129312.1 cytochrome P450 2U1 isoform X1 [Sus scrofa]
# XP_002717221.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Oryctolagus cuniculus]
# XP_010997363.1 PREDICTED: cytochrome P450 2U1 [Camelus dromedarius]
# XP_007938960.1 PREDICTED: cytochrome P450 2U1 [Orycteropus afer afer]
# XP_003796393.1 cytochrome P450 2U1 isoform X1 [Otolemur garnettii]
# XP_004040295.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Gorilla gorilla gorilla]
# NP_898898.1 cytochrome P450 2U1 [Homo sapiens]
# XP_004671492.1 PREDICTED: cytochrome P450 2U1 [Jaculus jaculus]
# XP_003929520.1 PREDICTED: cytochrome P450 2U1 [Saimiri boliviensis boliviensis]
# BAG64362.1 unnamed protein product [Homo sapiens]
# XP_017364494.1 PREDICTED: cytochrome P450 2U1 [Cebus capucinus imitator]
# XP_003410436.1 cytochrome P450 2U1 isoform X1 [Loxodonta africana]
# XP_007421378.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Python bivittatus]
# XP_010371512.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Rhinopithecus roxellana]
# XP_017824361.1 PREDICTED: cytochrome P450 2U1 [Callithrix jacchus]
# XP_012291909.1 cytochrome P450 2U1 [Aotus nancymaae]
# XP_017904722.1 PREDICTED: cytochrome P450 2U1 [Capra hircus]
# XP_011747414.1 PREDICTED: cytochrome P450 2U1 [Macaca nemestrina]
# XP_017708554.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Rhinopithecus bieti]
# XP_005555686.1 PREDICTED: cytochrome P450 2U1 [Macaca fascicularis]
# XP_023051615.1 cytochrome P450 2U1 isoform X1 [Piliocolobus tephrosceles]
# XP_011994146.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Ovis aries musimon]
# ARO89866.1 cytochrome P450 Cyp2u1 [Andrias davidianus]
# XP_007997667.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Chlorocebus sabaeus]
# XP_020016209.1 cytochrome P450 2U1 [Castor canadensis]
# NP_001106471.1 cytochrome P450 family 2 subfamily U member 1 [Xenopus tropicalis]
# XP_006212134.1 PREDICTED: cytochrome P450 2U1, partial [Vicugna pacos]
# DAA28880.1 TPA: cytochrome P450 2U1 [Bos taurus]
# XP_006096650.1 PREDICTED: cytochrome P450 2U1 [Myotis lucifugus]
# XP_005896309.1 PREDICTED: cytochrome P450 2U1 [Bos mutus]
# XP_006061937.1 PREDICTED: cytochrome P450 2U1-like [Bubalus bubalis]
# XP_022422796.1 cytochrome P450 2U1 isoform X1 [Delphinapterus leucas]
# XP_010951941.1 PREDICTED: LOW QUALITY PROTEIN: cytochrome P450 2U1 [Camelus bactrianus]
# XP_004703511.1 PREDICTED: cytochrome P450 2U1, partial [Echinops telfairi]
# XP_020757615.1 cytochrome P450 2U1 [Odocoileus virginianus texanus]
# XP_007452210.1 PREDICTED: cytochrome P450 2U1-like [Lipotes vexillifer]
# XP_007191063.1 PREDICTED: cytochrome P450 2U1-like isoform X1 [Balaenoptera acutorostrata scammoni]
# XP_002815089.2 PREDICTED: cytochrome P450 2U1 isoform X1 [Pongo abelii]
# XP_004380279.1 PREDICTED: cytochrome P450 2U1 [Trichechus manatus latirostris]
# XP_019783337.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Tursiops truncatus]
# BAG65487.1 unnamed protein product [Homo sapiens]
# XP_008953609.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Pan paniscus]
# XP_009446381.2 PREDICTED: cytochrome P450 2U1 isoform X1 [Pan troglodytes]
# XP_007100655.1 PREDICTED: cytochrome P450 2U1-like [Physeter catodon]
# XP_010856888.1 PREDICTED: cytochrome P450 2U1 [Bison bison bison]
# XP_019597472.1 PREDICTED: cytochrome P450 2U1 [Rhinolophus sinicus]
# XP_019491595.1 PREDICTED: cytochrome P450 2U1 [Hipposideros armiger]
# XP_016069983.1 PREDICTED: cytochrome P450 2U1, partial [Miniopterus natalensis]
# NP_001019950.1 cytochrome P450 2U1 [Rattus norvegicus]
# XP_005872504.1 PREDICTED: cytochrome P450 2U1 [Myotis brandtii]
# XP_021488968.1 cytochrome P450 2U1 isoform X1 [Meriones unguiculatus]
# XP_005978933.1 PREDICTED: cytochrome P450 2U1-like [Pantholops hodgsonii]
# XP_005357351.1 PREDICTED: cytochrome P450 2U1 [Microtus ochrogaster]
# NP_082092.2 cytochrome P450 2U1 [Mus musculus]
# XP_006629927.2 PREDICTED: cytochrome P450 2U1 [Lepisosteus oculatus]
# XP_001366063.1 PREDICTED: cytochrome P450 2U1 [Monodelphis domestica]
# XP_012374116.1 PREDICTED: cytochrome P450 2U1, partial [Dasypus novemcinctus]
# XP_020857009.1 cytochrome P450 2U1 isoform X1 [Phascolarctos cinereus]
# XP_019355655.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Alligator mississippiensis]
# XP_008842003.1 PREDICTED: cytochrome P450 2U1 [Nannospalax galili]
# XP_019377493.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Gavialis gangeticus]
# XP_021014502.1 cytochrome P450 2U1 isoform X1 [Mus caroli]
# XP_023361506.1 cytochrome P450 2U1 [Sarcophilus harrisii]
# XP_014414682.1 PREDICTED: cytochrome P450 2U1 [Camelus ferus]
# ELV13699.1 Cytochrome P450 2U1, partial [Tupaia chinensis]
# XP_008148480.1 PREDICTED: cytochrome P450 2U1 [Eptesicus fuscus]
# ERE89448.1 cytochrome P450 2U1-like protein [Cricetulus griseus]
# XP_004866353.1 cytochrome P450 2U1 [Heterocephalus glaber]
# KYO24444.1 cytochrome P450 2U1 isoform B [Alligator mississippiensis]
# XP_005082857.1 cytochrome P450 2U1 [Mesocricetus auratus]
# XP_006778968.2 PREDICTED: cytochrome P450 2U1 [Myotis davidii]
# XP_005406339.2 PREDICTED: cytochrome P450 2U1, partial [Chinchilla lanigera]
# XP_014694538.1 PREDICTED: cytochrome P450 2U1, partial [Equus asinus]
# XP_012354749.1 PREDICTED: cytochrome P450 2U1 [Nomascus leucogenys]
# KYO24445.1 cytochrome P450 2U1 isoform C [Alligator mississippiensis]
# XP_007624001.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Cricetulus griseus]
# XP_021052700.1 cytochrome P450 2U1 isoform X1 [Mus pahari]
# XP_007080878.1 PREDICTED: cytochrome P450 2U1 [Panthera tigris altaica]
# ELK06398.1 Cytochrome P450 2U1 [Pteropus alecto]
# EHH53889.1 hypothetical protein EGM_14598, partial [Macaca fascicularis]
# XP_004612799.1 PREDICTED: cytochrome P450 2U1, partial [Sorex araneus]
# XP_023108643.1 cytochrome P450 2U1 isoform X2 [Felis catus]
# XP_019272353.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Panthera pardus]
# XP_003468093.1 PREDICTED: cytochrome P450 2U1 [Cavia porcellus]
# EMP40787.1 Cytochrome P450 2U1 [Chelonia mydas]
# KTF87224.1 hypothetical protein cypCar_00019558 [Cyprinus carpio]
# XP_021794843.1 cytochrome P450 2U1 isoform X2 [Papio anubis]
# XP_010804215.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Bos taurus]
# XP_016124791.1 PREDICTED: cytochrome P450 2U1 [Sinocyclocheilus grahami]
# NP_001139036.1 cytochrome P450 2U1 [Danio rerio]
# KYO24443.1 cytochrome P450 2U1 isoform A [Alligator mississippiensis]
# XP_014050304.1 PREDICTED: cytochrome P450 2U1-like [Salmo salar]
# XP_019272361.1 PREDICTED: cytochrome P450 2U1 isoform X3 [Panthera pardus]
# XP_009238519.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Pongo abelii]
# XP_021429054.1 cytochrome P450 2U1-like [Oncorhynchus mykiss]
# XP_021429049.1 cytochrome P450 2U1-like isoform X1 [Oncorhynchus mykiss]
# XP_019110856.1 PREDICTED: cytochrome P450 2U1-like [Larimichthys crocea]
# KKF09825.1 Cytochrome P450 2U1 [Larimichthys crocea]
# XP_017556900.1 PREDICTED: cytochrome P450 2U1 [Pygocentrus nattereri]
# XP_010739611.2 PREDICTED: cytochrome P450 2U1 [Larimichthys crocea]
# XP_014065111.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Salmo salar]
# XP_007229530.1 cytochrome P450 2U1 [Astyanax mexicanus]
# XP_005940065.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Haplochromis burtoni]
# XP_004549474.1 cytochrome P450 2U1 [Maylandia zebra]
# XP_023129780.1 cytochrome P450 2U1 [Amphiprion ocellaris]
# XP_010371511.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Rhinopithecus roxellana]
# XP_020383892.1 cytochrome P450 2U1-like [Rhincodon typus]
# XP_007997668.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Chlorocebus sabaeus]
# XP_006787161.1 PREDICTED: cytochrome P450 2U1-like [Neolamprologus brichardi]
# ETE67196.1 Cytochrome protein, partial [Ophiophagus hannah]
# XP_023051617.1 cytochrome P450 2U1 isoform X2 [Piliocolobus tephrosceles]
# XP_005457042.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Oreochromis niloticus]
# XP_009205588.1 cytochrome P450 2U1 isoform X3 [Papio anubis]
# XP_011611201.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Takifugu rubripes]
# XP_022077378.1 cytochrome P450 2U1-like [Acanthochromis polyacanthus]
# BAB31223.1 unnamed protein product [Mus musculus]
# XP_011611202.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Takifugu rubripes]
# XP_005797710.1 cytochrome P450 2U1 [Xiphophorus maculatus]
# XP_020447513.1 cytochrome P450 2U1 isoform X1 [Monopterus albus]
# XP_010886716.1 PREDICTED: cytochrome P450 2U1 [Esox lucius]
# XP_008687731.1 PREDICTED: cytochrome P450 2U1 [Ursus maritimus]
# XP_019717376.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Hippocampus comes]
# XP_007560680.1 PREDICTED: cytochrome P450 2U1 [Poecilia formosa]
# XP_019956775.1 PREDICTED: cytochrome P450 2U1 [Paralichthys olivaceus]
# XP_005940067.1 PREDICTED: cytochrome P450 2U1 isoform X3 [Haplochromis burtoni]
# XP_008420764.1 PREDICTED: cytochrome P450 2U1 [Poecilia reticulata]
# XP_010778816.1 PREDICTED: cytochrome P450 2U1 [Notothenia coriiceps]
# XP_021488969.1 cytochrome P450 2U1 isoform X2 [Meriones unguiculatus]
# XP_008315701.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Cynoglossus semilaevis]
# XP_008315700.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Cynoglossus semilaevis]
# AGN04284.1 cytochrome P450 [Oryzias melastigma]
# CAG11477.1 unnamed protein product, partial [Tetraodon nigroviridis]
# XP_010639843.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Fukomys damarensis]
# XP_010639842.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Fukomys damarensis]
# XP_008759722.1 PREDICTED: cytochrome P450 2U1 isoform X3 [Rattus norvegicus]
# XP_013834422.1 cytochrome P450 2U1 isoform X2 [Sus scrofa]
# KFO25848.1 Cytochrome P450 2U1 [Fukomys damarensis]
# XP_007421379.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Python bivittatus]
# XP_005207709.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Bos taurus]
# KTF79021.1 hypothetical protein cypCar_00041961 [Cyprinus carpio]
# XP_016429803.1 PREDICTED: cytochrome P450 2U1-like [Sinocyclocheilus rhinocerous]
# XP_007899581.1 PREDICTED: cytochrome P450 2U1 [Callorhinchus milii]
# XP_021794846.1 cytochrome P450 2U1 isoform X4 [Papio anubis]
# XP_020857012.1 cytochrome P450 2U1 isoform X2 [Phascolarctos cinereus]
# XP_021330598.1 cytochrome P450 2U1 isoform X1 [Danio rerio]
# EDL82214.1 cytochrome P450, family 2, subfamily u, polypeptide 1 [Rattus norvegicus]
# ERE89449.1 cytochrome P450 2U1-like protein [Cricetulus griseus]
# XP_008759721.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Rattus norvegicus]
# XP_019717377.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Hippocampus comes]
# XP_020447514.1 cytochrome P450 2U1 isoform X2 [Monopterus albus]
# XP_013834424.1 cytochrome P450 2U1 isoform X3 [Sus scrofa]
# XP_021429050.1 cytochrome P450 2U1-like isoform X2 [Oncorhynchus mykiss]
# XP_005457043.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Oreochromis niloticus]
# XP_014065112.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Salmo salar]
# EDL12202.1 mCG10210, isoform CRA_b, partial [Mus musculus]
# XP_019633722.1 PREDICTED: cytochrome P450 2U1-like isoform X1 [Branchiostoma belcheri]
# XP_019633723.1 PREDICTED: cytochrome P450 2U1-like isoform X2 [Branchiostoma belcheri]
# AAI09451.1 Cyp2v1 protein [Danio rerio]
# PIO29941.1 hypothetical protein AB205_0044010, partial [Rana catesbeiana]
# XP_002587334.1 hypothetical protein BRAFLDRAFT_61459 [Branchiostoma floridae]
# XP_019640006.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_019640067.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_019621545.1 PREDICTED: cytochrome P450 2U1-like isoform X2 [Branchiostoma belcheri]
# XP_019625214.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_019621544.1 PREDICTED: cytochrome P450 2U1-like isoform X1 [Branchiostoma belcheri]
# XP_002588060.1 hypothetical protein BRAFLDRAFT_59209 [Branchiostoma floridae]
# XP_019621628.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_019631423.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# AAI55663.1 LOC563369 protein, partial [Danio rerio]
# XP_019613674.1 PREDICTED: cytochrome P450 2U1-like isoform X1 [Branchiostoma belcheri]
# XP_019628304.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# AGN04335.1 cytochrome P450, partial [Oryzias melastigma]
# XP_786956.3 PREDICTED: cytochrome P450 2U1 [Strongylocentrotus purpuratus]
# AAH56589.1 Wu:fc21h01 protein, partial [Danio rerio]
# XP_019633621.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_002585682.1 hypothetical protein BRAFLDRAFT_289920 [Branchiostoma floridae]
# AAI52007.1 Zgc:171945 protein [Danio rerio]
# EFB15022.1 hypothetical protein PANDA_005452, partial [Ailuropoda melanoleuca]
# XP_019623097.1 PREDICTED: uncharacterized protein LOC109469135 [Branchiostoma belcheri]
# XP_019647512.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# AGN04307.1 cytochrome P450 [Oryzias melastigma]
# AGN04311.1 cytochrome P450 [Oryzias melastigma]
# BAG37780.1 unnamed protein product [Homo sapiens]
# XP_002594674.1 hypothetical protein BRAFLDRAFT_271642 [Branchiostoma floridae]
# XP_002587338.1 hypothetical protein BRAFLDRAFT_100536 [Branchiostoma floridae]
# XP_006822041.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# XP_006811947.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# XP_022091223.1 cytochrome P450 2U1-like [Acanthaster planci]
# AGN04309.1 cytochrome P450 [Oryzias melastigma]
# XP_002585796.1 hypothetical protein BRAFLDRAFT_97633 [Branchiostoma floridae]
# XP_002738774.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# NP_001020728.2 cytochrome P450 [Danio rerio]
# AGN04330.1 cytochrome P450 [Oryzias melastigma]
# XP_002594675.1 hypothetical protein BRAFLDRAFT_287037 [Branchiostoma floridae]
# XP_002594499.1 hypothetical protein BRAFLDRAFT_59802 [Branchiostoma floridae]
# AAM90905.1 cytochrome P450 [Danio rerio]
# XP_019640068.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_019613672.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_002590802.1 hypothetical protein BRAFLDRAFT_121938 [Branchiostoma floridae]
# XP_019638039.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_019645803.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# AGN04296.1 cytochrome P450 [Oryzias melastigma]
# ELR59612.1 hypothetical protein M91_15035, partial [Bos mutus]
# OCA37567.1 hypothetical protein XENTR_v90011300mg [Xenopus tropicalis]
# AAI54114.1 LOC100127674 protein [Xenopus tropicalis]
# XP_019629809.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_002740620.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# AGN04277.1 cytochrome P450 [Oryzias melastigma]
# XP_002589623.1 hypothetical protein BRAFLDRAFT_236550, partial [Branchiostoma floridae]
# XP_015245839.1 PREDICTED: cytochrome P450 2U1 [Cyprinodon variegatus]
# XP_002595495.1 hypothetical protein BRAFLDRAFT_57483 [Branchiostoma floridae]
# AGN04312.1 cytochrome P450 [Oryzias melastigma]
# XP_007065771.1 PREDICTED: talin-2-like [Chelonia mydas]
# NP_001120541.1 uncharacterized protein LOC100145695 [Xenopus tropicalis]
# BAA92374.1 cytochrome P450 [Danio rerio]
# AAI68071.1 hypothetical protein LOC100145695 [Xenopus tropicalis]
# BAF62160.1 cytochrome P450 [Danio rerio]
# NP_001083310.1 uncharacterized protein LOC398859 [Xenopus laevis]
# XP_002594509.1 hypothetical protein BRAFLDRAFT_87704 [Branchiostoma floridae]
# XP_002597633.1 hypothetical protein BRAFLDRAFT_225868 [Branchiostoma floridae]
# XP_002588643.1 hypothetical protein BRAFLDRAFT_116025 [Branchiostoma floridae]
# AAB87636.1 cytochrome P450 monooxygenase [Mus musculus]
# NP_001085963.1 MGC82914 protein [Xenopus laevis]
# BAC28391.1 unnamed protein product [Mus musculus]
# AAA41055.1 debrisoquine 4-hydroxylase [Rattus norvegicus]
# OXB57021.1 hypothetical protein ASZ78_000590, partial [Callipepla squamata]
# XP_021429052.1 cytochrome P450 2U1-like isoform X3 [Oncorhynchus mykiss]
# OXB57020.1 hypothetical protein ASZ78_000589, partial [Callipepla squamata]
# OXB53467.1 hypothetical protein ASZ78_012035 [Callipepla squamata]
# XP_002589622.1 hypothetical protein BRAFLDRAFT_236584, partial [Branchiostoma floridae]
# XP_021373153.1 cytochrome P450 2U1-like [Mizuhopecten yessoensis]
# XP_002738775.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# OWF40976.1 Cytochrome P450 2U1 [Mizuhopecten yessoensis]
# OXB82136.1 hypothetical protein H355_009015 [Colinus virginianus]
# XP_012823492.1 PREDICTED: uncharacterized protein LOC100145695 isoform X1 [Xenopus tropicalis]
# XP_002591143.1 hypothetical protein BRAFLDRAFT_253672 [Branchiostoma floridae]
# AAA79023.1 testosterone 16-alpha-hydroxylase [Mus musculus domesticus]
# XP_019936176.1 PREDICTED: uncharacterized protein LOC109625408 [Paralichthys olivaceus]
# XP_019614668.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# OCA38868.1 hypothetical protein XENTR_v900123512mg, partial [Xenopus tropicalis]
# XP_002740465.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# XP_002589617.1 hypothetical protein BRAFLDRAFT_224685, partial [Branchiostoma floridae]
# EDL04504.1 mCG20388, isoform CRA_a, partial [Mus musculus]
# OCA38910.1 hypothetical protein XENTR_v90012386mg [Xenopus tropicalis]
# XP_010014610.1 PREDICTED: uncharacterized protein LOC104407121 [Nestor notabilis]
# XP_019629979.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# AAA40427.1 testosterone 16-alpha-hydroxylase [Mus musculus]
# CAA36270.1 cytochrome P450 IID3 protein [Rattus norvegicus]
# BAE25635.1 unnamed protein product [Mus musculus]
# XP_019641598.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# AAC52245.1 P45016a-ms1 [Mus spretus]
# CAA30807.1 cytochrome P450 db1 [Homo sapiens]
# AGN04310.1 cytochrome P450 [Oryzias melastigma]
# CAA36271.1 cytochrome P450 IID3 protein [Rattus norvegicus]
# AAA39876.1 cytochrome P450-16-alpha [Mus musculus domesticus]
# OCA38865.1 hypothetical protein XENTR_v90012348mg [Xenopus tropicalis]
# XP_022084337.1 cytochrome P450 2U1-like [Acanthaster planci]
# XP_019627491.1 PREDICTED: LOW QUALITY PROTEIN: cytochrome P450 2U1-like [Branchiostoma belcheri]
# OCA38908.1 hypothetical protein XENTR_v90012384mg [Xenopus tropicalis]
# AGN04285.1 cytochrome P450 [Oryzias melastigma]
# BAE28954.1 unnamed protein product [Mus musculus]
# XP_022090540.1 cytochrome P450 2U1-like [Acanthaster planci]
# AAC52246.1 P45016a-ms2 [Mus spretus]
# AGN04294.1 cytochrome P450 [Oryzias melastigma]
# XP_019627490.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_002593703.1 hypothetical protein BRAFLDRAFT_199519, partial [Branchiostoma floridae]
# BAB31202.1 unnamed protein product, partial [Mus musculus]
# CAG01688.1 unnamed protein product, partial [Tetraodon nigroviridis]
# XP_002589624.1 hypothetical protein BRAFLDRAFT_236546, partial [Branchiostoma floridae]
# XP_002590801.1 hypothetical protein BRAFLDRAFT_114435 [Branchiostoma floridae]
# XP_002593414.1 hypothetical protein BRAFLDRAFT_277070 [Branchiostoma floridae]
# XP_002595581.1 hypothetical protein BRAFLDRAFT_56933 [Branchiostoma floridae]
# AAH53412.1 LOC402847 protein, partial [Danio rerio]
# BAD92729.1 debrisoquine 4-hydroxylase mutant allele variant, partial [Homo sapiens]
# XP_017159757.1 PREDICTED: uncharacterized protein LOC103464053 [Poecilia reticulata]
# AGN04283.1 cytochrome P450 [Oryzias melastigma]
# XP_019630647.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# AAI65796.1 Zgc:101673 protein [Danio rerio]
# KTG05487.1 hypothetical protein cypCar_00020978 [Cyprinus carpio]
# KTG07253.1 hypothetical protein cypCar_00014834 [Cyprinus carpio]
# XP_019628033.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_014670236.1 PREDICTED: cytochrome P450 2U1-like isoform X1 [Priapulus caudatus]
# CAG04834.1 unnamed protein product, partial [Tetraodon nigroviridis]
# XP_002598693.1 hypothetical protein BRAFLDRAFT_250482 [Branchiostoma floridae]
# EHH65892.1 hypothetical protein EGM_02754 [Macaca fascicularis]
# XP_019646677.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_006823767.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# XP_019617750.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_785753.3 PREDICTED: cytochrome P450 2U1 [Strongylocentrotus purpuratus]
# XP_002589616.1 hypothetical protein BRAFLDRAFT_81584, partial [Branchiostoma floridae]
# XP_006823766.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# XP_002597939.1 hypothetical protein BRAFLDRAFT_221364, partial [Branchiostoma floridae]
# XP_006811948.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# EHH20288.1 hypothetical protein EGK_03109 [Macaca mulatta]
# AAI29617.1 LOC100037191 protein, partial [Xenopus laevis]
# XP_022103601.1 cytochrome P450 2U1-like isoform X1 [Acanthaster planci]
# OXB61435.1 hypothetical protein ASZ78_015541 [Callipepla squamata]
# XP_019642956.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# PIO35744.1 hypothetical protein AB205_0085190, partial [Rana catesbeiana]
# CDQ94506.1 unnamed protein product, partial [Oncorhynchus mykiss]
# XP_019615816.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_019619827.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_002119454.1 PREDICTED: cytochrome P450 2U1-like [Ciona intestinalis]
# XP_014674645.1 PREDICTED: cytochrome P450 2U1-like [Priapulus caudatus]
# NP_001073833.1 uncharacterized protein LOC785824 [Bos taurus]
# CAF95844.1 unnamed protein product, partial [Tetraodon nigroviridis]
# NP_001001212.1 uncharacterized protein LOC407870 [Xenopus tropicalis]
# PKU35087.1 cytochrome p450 2k4-like [Limosa lapponica baueri]
# CAA48149.1 cytochrome P-450IID, partial [Bos taurus]
# XP_019642928.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# OCA25690.1 hypothetical protein XENTR_v90020998mg [Xenopus tropicalis]
# XP_002587465.1 hypothetical protein BRAFLDRAFT_238212, partial [Branchiostoma floridae]
# XP_001640254.1 predicted protein [Nematostella vectensis]
# OXB80509.1 hypothetical protein H355_016299, partial [Colinus virginianus]
# AAA41045.1 cytochrome P450, partial [Rattus norvegicus]
# AAH89723.1 LOC548374 protein, partial [Xenopus tropicalis]
# XP_003727710.1 PREDICTED: cytochrome P450 2U1 [Strongylocentrotus purpuratus]
# CDQ71941.1 unnamed protein product [Oncorhynchus mykiss]
# AAH45948.1 Cyp2j28 protein [Danio rerio]
# XP_002589620.1 hypothetical protein BRAFLDRAFT_99229 [Branchiostoma floridae]
# XP_019624571.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# NP_001090686.1 uncharacterized protein LOC100036663 [Xenopus tropicalis]
# XP_019619982.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# KTF91078.1 hypothetical protein cypCar_00019010 [Cyprinus carpio]
# XP_012819466.1 PREDICTED: uncharacterized protein LOC100036663 isoform X1 [Xenopus tropicalis]
# XP_002589192.1 hypothetical protein BRAFLDRAFT_74651 [Branchiostoma floridae]
# XP_014670237.1 PREDICTED: cytochrome P450 2U1-like isoform X2 [Priapulus caudatus]
# AAA41043.1 cytochrome P450 [Rattus norvegicus]
# XP_786300.2 PREDICTED: cytochrome P450 2U1-like [Strongylocentrotus purpuratus]
# KTF79658.1 hypothetical protein cypCar_00027358 [Cyprinus carpio]
# AAI34886.1 Cyp2k19 protein, partial [Danio rerio]
# AAI25904.1 Cyp2k19 protein, partial [Danio rerio]
# AAH81666.1 Cyp2k19 protein, partial [Danio rerio]
# NP_001096373.1 uncharacterized protein LOC100124967 [Xenopus tropicalis]
# PIO35743.1 hypothetical protein AB205_0085190, partial [Rana catesbeiana]
# XP_006821776.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# XP_019631171.1 PREDICTED: cytochrome P450 2U1-like isoform X2 [Branchiostoma belcheri]
# OCA35992.1 hypothetical protein XENTR_v90015308mg [Xenopus tropicalis]
# PKU36625.1 cytochrome p450 2k4-like [Limosa lapponica baueri]
# OCA38863.1 hypothetical protein XENTR_v90012348mg [Xenopus tropicalis]
# XP_002595884.1 hypothetical protein BRAFLDRAFT_107081 [Branchiostoma floridae]
# OXB53465.1 hypothetical protein ASZ78_012033, partial [Callipepla squamata]
# XP_012819468.1 PREDICTED: uncharacterized protein LOC100036663 isoform X2 [Xenopus tropicalis]
# XP_009065179.1 hypothetical protein LOTGIDRAFT_155365 [Lottia gigantea]
# XP_019635866.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# AAA31175.1 cytochrome P450IIC3 [Oryctolagus cuniculus]
# XP_005101694.1 PREDICTED: cytochrome P450 2U1-like [Aplysia californica]
# XP_019631170.1 PREDICTED: cytochrome P450 2U1-like isoform X1 [Branchiostoma belcheri]
# DAA29095.1 TPA: hypothetical protein LOC785824 [Bos taurus]
# XP_013774211.1 cytochrome P450 2U1-like [Limulus polyphemus]
# AAH95246.1 Zgc:136371 protein, partial [Danio rerio]
# EDL24215.1 mCG10948 [Mus musculus]
# NP_001120235.1 uncharacterized protein LOC100145285 [Xenopus tropicalis]
# OCA25691.1 hypothetical protein XENTR_v90020999mg [Xenopus tropicalis]
# OXB82134.1 hypothetical protein H355_009013 [Colinus virginianus]
# EDL04492.1 mCG4193, isoform CRA_b [Mus musculus]
# XP_002589615.1 hypothetical protein BRAFLDRAFT_224706, partial [Branchiostoma floridae]
# OCA25685.1 hypothetical protein XENTR_v90020992mg [Xenopus tropicalis]
# OXB52284.1 hypothetical protein ASZ78_007469 [Callipepla squamata]
# NP_001164602.1 cytochrome P-450 precursor [Oryctolagus cuniculus]
# XP_002599331.1 hypothetical protein BRAFLDRAFT_56886 [Branchiostoma floridae]
# XP_002586690.1 hypothetical protein BRAFLDRAFT_247676, partial [Branchiostoma floridae]
# OXB67595.1 hypothetical protein ASZ78_004713 [Callipepla squamata]
# XP_019624239.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# XP_022095211.1 cytochrome P450 2U1-like [Acanthaster planci]
# PIK48289.1 putative cytochrome P450 2U1-like [Apostichopus japonicus]
# AGN04295.1 cytochrome P450 [Oryzias melastigma]
# XP_002588542.1 hypothetical protein BRAFLDRAFT_220702, partial [Branchiostoma floridae]
# XP_009059983.1 hypothetical protein LOTGIDRAFT_228903 [Lottia gigantea]
# pdb|1PQ2|A Chain A, Crystal Structure Of Human Drug Metabolizing Cytochrome P450 2c8
# XP_017193723.1 PREDICTED: cytochrome P-450 [Oryctolagus cuniculus]
# XP_002586865.1 hypothetical protein BRAFLDRAFT_129817 [Branchiostoma floridae]
# NP_001083455.1 cytochrome P450 family 2 subfamily F member 1 S homeolog [Xenopus laevis]
# AAA52161.1 cytochrome P-450 S-mephenytoin 4-hydroxylase, partial [Homo sapiens]
# XP_022103600.1 cytochrome P450 2U1-like [Acanthaster planci]
# BAF98714.1 unnamed protein product [Homo sapiens]
# BAF85442.1 unnamed protein product [Homo sapiens]
# AAA52160.1 cytochrome P-450 S-mephenytoin 4-hydroxylase, partial [Homo sapiens]
# AAA31211.1 cytochrome P-450, partial [Oryctolagus cuniculus]
# XP_015666064.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Protobothrops mucrosquamatus]
# KKF09131.1 Bardet-Biedl syndrome 2 protein [Larimichthys crocea]
# OXB55017.1 hypothetical protein ASZ78_003709, partial [Callipepla squamata]
# OXB75040.1 hypothetical protein H355_001447 [Colinus virginianus]
# XP_003728047.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Strongylocentrotus purpuratus]
# NP_001036243.2 cytochrome P450-like [Danio rerio]
# XP_002588092.1 hypothetical protein BRAFLDRAFT_59786 [Branchiostoma floridae]
# XP_020642776.1 uncharacterized protein LOC110075668 [Pogona vitticeps]
# XP_009050295.1 hypothetical protein LOTGIDRAFT_142374 [Lottia gigantea]
# XP_782513.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Strongylocentrotus purpuratus]
# OXB61356.1 hypothetical protein ASZ78_011978 [Callipepla squamata]
# AAA35739.1 cytochrome P-450 1 [Homo sapiens]
# OXB52747.1 hypothetical protein ASZ78_013046 [Callipepla squamata]
# XP_017949981.1 PREDICTED: uncharacterized protein LOC100124950 isoform X2 [Xenopus tropicalis]
# XP_015919907.1 cytochrome P450 2U1-like [Parasteatoda tepidariorum]
# OCA38864.1 hypothetical protein XENTR_v90012348mg [Xenopus tropicalis]
# XP_782351.2 PREDICTED: cytochrome P450 2U1 isoform X2 [Strongylocentrotus purpuratus]
# PKU38957.1 hypothetical protein llap_10744 [Limosa lapponica baueri]
# OPJ85557.1 hypothetical protein AV530_001764 [Patagioenas fasciata monilis]
# AAA31434.1 cytochrome P-450 [Oryctolagus cuniculus]
# XP_022099104.1 cytochrome P450 2U1-like isoform X1 [Acanthaster planci]
# AAA41024.1 cytochrome p-450, partial [Rattus norvegicus]
# OPJ85555.1 hypothetical protein AV530_001764 [Patagioenas fasciata monilis]
# AAO49806.1 cytochrome P450 [Homo sapiens]
# OCA25675.1 hypothetical protein XENTR_v90020984mg [Xenopus tropicalis]
# AAA03647.1 testosterone 16a-hydroxylase type b [Mus musculus]
# XP_002739928.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# XP_022094290.1 cytochrome P450 2U1-like [Acanthaster planci]
# XP_010001638.1 PREDICTED: uncharacterized protein LOC104393815 [Chaetura pelagica]
# OCA35977.1 hypothetical protein XENTR_v900152952mg, partial [Xenopus tropicalis]
# PIK46998.1 putative cytochrome P450 2U1-like [Apostichopus japonicus]
# XP_782458.3 PREDICTED: cytochrome P450 2U1 [Strongylocentrotus purpuratus]
# GAV03411.1 hypothetical protein RvY_13838 [Ramazzottius varieornatus]
# NP_001096359.1 uncharacterized protein LOC100124950 precursor [Xenopus tropicalis]
# OCA25674.1 hypothetical protein XENTR_v90020983mg [Xenopus tropicalis]
# EFB16313.1 hypothetical protein PANDA_012937, partial [Ailuropoda melanoleuca]
# EDL24217.1 mCG10947 [Mus musculus]
# ELT89059.1 hypothetical protein CAPTEDRAFT_127844 [Capitella teleta]
# XP_002599603.1 hypothetical protein BRAFLDRAFT_58542 [Branchiostoma floridae]
# AAA37514.1 testosterone 16-alpha-hydroxylase (CC), partial [Mus musculus]
# XP_022087533.1 cytochrome P450 2U1-like [Acanthaster planci]
# XP_006825849.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# XP_017949212.1 PREDICTED: uncharacterized protein LOC100036663 isoform X3 [Xenopus tropicalis]
# OXB77677.1 hypothetical protein H355_003506 [Colinus virginianus]
# XP_009858562.1 PREDICTED: cytochrome P450 2U1 [Ciona intestinalis]
# XP_002587615.1 hypothetical protein BRAFLDRAFT_96455 [Branchiostoma floridae]
# XP_019617409.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# PIO33477.1 hypothetical protein AB205_0042550 [Rana catesbeiana]
# XP_012819500.1 PREDICTED: cytochrome P450 family 2 subfamily F member 1 isoform X1 [Xenopus tropicalis]
# XP_019616829.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# OXB52342.1 hypothetical protein ASZ78_004340 [Callipepla squamata]
# BAC34051.1 unnamed protein product [Mus musculus]
# XP_002589621.1 hypothetical protein BRAFLDRAFT_236616, partial [Branchiostoma floridae]
# EDL24230.1 mCG7659, isoform CRA_a [Mus musculus]
# AGN04287.1 cytochrome P450 [Oryzias melastigma]
# AAA40424.1 testosterone 16-alpha-hydroxylase [Mus musculus]
# AAH85198.1 LOC495506 protein, partial [Xenopus laevis]
# OWK16081.1 hypothetical protein Celaphus_00004380 [Cervus elaphus hippelaphus]
# XP_002588749.1 hypothetical protein BRAFLDRAFT_256078, partial [Branchiostoma floridae]
# AAI60556.1 LOC733530 protein [Xenopus tropicalis]
# OXB62104.1 hypothetical protein ASZ78_010509 [Callipepla squamata]
# OXB82725.1 hypothetical protein H355_000423 [Colinus virginianus]
# OXB77676.1 hypothetical protein H355_003505 [Colinus virginianus]
# GAU95786.1 hypothetical protein RvY_07343 [Ramazzottius varieornatus]
# NP_001083374.2 uncharacterized protein LOC398891 [Xenopus laevis]
# AGN04306.1 cytochrome P450 [Oryzias melastigma]
# ELK00221.1 Ammonium transporter Rh type A [Pteropus alecto]
# CDQ74565.1 unnamed protein product [Oncorhynchus mykiss]
# EDK97563.1 hypothetical protein F730023N20, isoform CRA_a [Mus musculus]
# BAB25834.1 unnamed protein product, partial [Mus musculus]
# XP_013091704.1 PREDICTED: cytochrome P450 2U1-like isoform X3 [Biomphalaria glabrata]
# AGN04308.1 cytochrome P450 [Oryzias melastigma]
# AAA41007.1 cytochrome P450 [Rattus norvegicus]
# ELU05557.1 hypothetical protein CAPTEDRAFT_164179 [Capitella teleta]
# OXB62880.1 hypothetical protein ASZ78_003046 [Callipepla squamata]
# pdb|1R9O|A Chain A, Crystal Structure Of P4502c9 With Flurbiprofen Bound
# AAO52736.1 cytochrome P450 [Mus musculus]
# AAB23864.2 cytochrome P-450 [Homo sapiens]
# pdb|1DT6|A Chain A, Structure Of Mammalian Cytochrome P450 2c5
# OXB61357.1 hypothetical protein ASZ78_011979 [Callipepla squamata]
# XP_009057084.1 hypothetical protein LOTGIDRAFT_217014 [Lottia gigantea]
# XP_002586047.1 hypothetical protein BRAFLDRAFT_145601, partial [Branchiostoma floridae]
# BAA00123.1 cytochrome P-450, partial [Homo sapiens]
# NP_001037917.1 cytochrome P450 family 2 subfamily F member 1 precursor [Xenopus tropicalis]
# EPY77315.1 hypothetical protein CB1_001276010 [Camelus ferus]
# XP_009057255.1 hypothetical protein LOTGIDRAFT_121674 [Lottia gigantea]
# XP_009858778.2 PREDICTED: cytochrome P450 2U1-like isoform X1 [Ciona intestinalis]
# KTF85127.1 hypothetical protein cypCar_00044335 [Cyprinus carpio]
# ETE58195.1 Cytochrome protein, partial [Ophiophagus hannah]
# AAB02144.1 cytochrome P-450 [Rattus norvegicus]
# KYO44817.1 hypothetical protein Y1Q_0006983 [Alligator mississippiensis]
# AAA41056.1 cytochrome P-450 [Rattus norvegicus]
# XP_002731713.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# OCA35989.1 hypothetical protein XENTR_v90015305mg [Xenopus tropicalis]
# XP_002120735.1 PREDICTED: cytochrome P450 2U1-like [Ciona intestinalis]
# pdb|1Z10|A Chain A, Crystal Structure Of Human Microsomal P450 2a6 With Coumarin Bound
# EDL30915.1 mCG15473 [Mus musculus]
# XP_003724748.2 PREDICTED: cytochrome P450 2U1 [Strongylocentrotus purpuratus]
# CAG12753.1 unnamed protein product [Tetraodon nigroviridis]
# AAA41059.1 cytochrome P-450 IIC13 [Rattus norvegicus]
# XP_005111348.2 PREDICTED: cytochrome P450 2U1-like [Aplysia californica]
# EHH25617.1 hypothetical protein EGK_21513 [Macaca mulatta]
# AAA52157.1 cytochrome P-450 S-mephenytoin 4-hydroxylase, partial [Homo sapiens]
# CAG06313.1 unnamed protein product, partial [Tetraodon nigroviridis]
# EDL77990.1 rCG36686, isoform CRA_a [Rattus norvegicus]
# XP_011677992.1 PREDICTED: cytochrome P450 2U1 isoform X2 [Strongylocentrotus purpuratus]
# EHB11280.1 Transcription factor 20 [Heterocephalus glaber]
# XP_013091703.1 PREDICTED: cytochrome P450 2U1-like isoform X2 [Biomphalaria glabrata]
# EDL97782.1 rCG53515, isoform CRA_a [Rattus norvegicus]
# BAA04555.1 cytochrome P-450 [Mus musculus]
# OQV14575.1 Cytochrome P450 2U1 [Hypsibius dujardini]
# AAA31210.1 cytochrome P-450, partial [Oryctolagus cuniculus]
# PIO27463.1 hypothetical protein AB205_0207860 [Rana catesbeiana]
# XP_002735624.2 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# OXB67593.1 hypothetical protein ASZ78_004711 [Callipepla squamata]
# NP_038837.1 cytochrome P450, family 2, subfamily g, polypeptide 1 precursor [Mus musculus]
# AAD13719.1 cytochrome P450 [Mus musculus]
# OWK15696.1 hypothetical protein Celaphus_00004378 [Cervus elaphus hippelaphus]
# XP_013091702.1 PREDICTED: cytochrome P450 2U1-like isoform X1 [Biomphalaria glabrata]
# AAA41046.1 cytochrome P450b [Rattus norvegicus]
# ELU08157.1 hypothetical protein CAPTEDRAFT_130539 [Capitella teleta]
# AGN04293.1 cytochrome P450 [Oryzias melastigma]
# NP_001079915.1 uncharacterized protein LOC379605 [Xenopus laevis]
# XP_005111347.1 PREDICTED: cytochrome P450 2U1-like [Aplysia californica]
# ELU05903.1 hypothetical protein CAPTEDRAFT_153347 [Capitella teleta]
# EHH25402.1 hypothetical protein EGK_21590 [Macaca mulatta]
# AAA41058.1 cytochrome P450f, partial [Rattus norvegicus]
# EHH30060.1 hypothetical protein EGK_10644 [Macaca mulatta]
# EHH59604.1 hypothetical protein EGM_09758 [Macaca fascicularis]
# XP_787466.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Strongylocentrotus purpuratus]
# AAA52138.1 cytochrome P450IIA4 [Homo sapiens]
# XP_017949980.1 PREDICTED: uncharacterized protein LOC100124950 isoform X1 [Xenopus tropicalis]
# NP_001120076.1 uncharacterized protein LOC100145084 [Xenopus tropicalis]
# AAA31209.1 cytochrome P-450 1 [Oryctolagus cuniculus]
# ELR53757.1 hypothetical protein M91_03081, partial [Bos mutus]
# AAH89736.1 cyp2c37-prov protein, partial [Xenopus tropicalis]
# XP_002587487.1 hypothetical protein BRAFLDRAFT_238270 [Branchiostoma floridae]
# AAA37797.1 P450-15-alpha hydroxylase I, partial [Mus musculus]
# EHH30061.1 hypothetical protein EGK_10645 [Macaca mulatta]
# AAH60455.1 MGC68527 protein [Xenopus laevis]
# pdb|4GQS|A Chain A, Structure Of Human Microsomal Cytochrome P450 (cyp) 2c19
# OXB82428.1 hypothetical protein H355_000686 [Colinus virginianus]
# ELT90088.1 hypothetical protein CAPTEDRAFT_147788 [Capitella teleta]
# AAA41070.2 olfactory-specific cytochrome P-450 (P-450olf1), partial [Rattus norvegicus]
# PIO39127.1 hypothetical protein AB205_0137850 [Rana catesbeiana]
# OXB62105.1 hypothetical protein ASZ78_010510 [Callipepla squamata]
# AGT20530.1 mutant cytochrome P450 [synthetic construct]
# XP_013420528.1 PREDICTED: cytochrome P450 2U1-like isoform X1 [Lingula anatina]
# EAW57017.1 cytochrome P450, family 2, subfamily F, polypeptide 1, isoform CRA_a [Homo sapiens]
# XP_013394794.1 PREDICTED: cytochrome P450 2U1-like [Lingula anatina]
# pdb|3E4E|A Chain A, Human Cytochrome P450 2e1 In Complex With The Inhibitor 4- Methylpyrazole
# AAH65455.1 Zgc:55856 protein [Danio rerio]
# AAP33890.1 coumarin 7-hydroxylase [Sus scrofa]
# OWA53859.1 Cytochrome P450 2U1 [Hypsibius dujardini]
# XP_008309348.2 PREDICTED: uncharacterized protein LOC103379543 [Cynoglossus semilaevis]
# XP_006812434.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# OXB74099.1 hypothetical protein H355_015230 [Colinus virginianus]
# AAA88511.1 cytochrome P450 IIA3, partial [Rattus norvegicus]
# XP_012819479.1 PREDICTED: MGC69416 protein isoform X2 [Xenopus tropicalis]
# OCA25681.1 hypothetical protein XENTR_v900209881mg, partial [Xenopus tropicalis]
# NP_001015757.1 MGC107969 protein [Xenopus tropicalis]
# KTG07254.1 hypothetical protein cypCar_00014835 [Cyprinus carpio]
# XP_009858745.2 PREDICTED: cytochrome P450 2U1-like [Ciona intestinalis]
# AAA31212.1 cytochrome P-450, partial [Oryctolagus cuniculus]
# OCA38866.1 hypothetical protein XENTR_v90012348mg [Xenopus tropicalis]
# BAF83511.1 unnamed protein product [Homo sapiens]
# OQV25636.1 Cytochrome P450 2U1 [Hypsibius dujardini]
# XP_009053804.1 hypothetical protein LOTGIDRAFT_117066 [Lottia gigantea]
# XP_002596348.1 hypothetical protein BRAFLDRAFT_76147 [Branchiostoma floridae]
# CDQ66179.1 unnamed protein product [Oncorhynchus mykiss]
# BAE24131.1 unnamed protein product [Mus musculus]
# OCA25682.1 hypothetical protein XENTR_v90020989mg [Xenopus tropicalis]
# EDL24204.1 mCG22750 [Mus musculus]
# PIO40987.1 hypothetical protein AB205_0206370 [Rana catesbeiana]
# XP_011664220.1 PREDICTED: cytochrome P450 2U1 [Strongylocentrotus purpuratus]
# KYO44819.1 hypothetical protein Y1Q_0006985 [Alligator mississippiensis]
# AAB40520.1 cytochrome P450 [Homo sapiens]
# KYO44825.1 hypothetical protein Y1Q_0006990 [Alligator mississippiensis]
# AAH91704.1 LOC619584 protein, partial [Xenopus tropicalis]
# AAA31213.1 cytochrome P450 isozyme 3a, partial [Oryctolagus cuniculus]
# XP_014788787.1 PREDICTED: cytochrome P450 2U1-like [Octopus bimaculoides]
# NP_001123668.1 uncharacterized protein LOC100170416 [Xenopus tropicalis]
# OXB58270.1 hypothetical protein ASZ78_010464 [Callipepla squamata]
# PIK49892.1 putative cytochrome P450 2U1 [Apostichopus japonicus]
# AAA31219.1 cytochrome P450, partial [Oryctolagus cuniculus]
# OWA52480.1 Cytochrome P450 2U1 [Hypsibius dujardini]
# AAB40519.1 cytochrome P450 [Homo sapiens]
# AAA35737.1 debrisoquine 4-hydroxylase [Homo sapiens]
# AGQ48062.1 cytochrome P450 monooxygenase [Coptotermes formosanus]
# KYO44820.1 hypothetical protein Y1Q_0006985 [Alligator mississippiensis]
# NP_001083388.2 uncharacterized protein LOC398899 [Xenopus laevis]
# XP_019614409.1 PREDICTED: cytochrome P450 2U1-like [Branchiostoma belcheri]
# CAA39087.1 cytochrome P-450 [Rattus norvegicus]
# XP_009060686.1 hypothetical protein LOTGIDRAFT_179079 [Lottia gigantea]
# AAA36660.1 cytochrome P450 [Homo sapiens]
# XP_013091701.1 PREDICTED: cytochrome P450 2U1-like [Biomphalaria glabrata]
# EFB16551.1 hypothetical protein PANDA_017634, partial [Ailuropoda melanoleuca]
# AGN04292.1 cytochrome P450 [Oryzias melastigma]
# EMP27507.1 Eukaryotic translation initiation factor 4E type 2 [Chelonia mydas]
# PIK51744.1 putative cytochrome P450 2U1 [Apostichopus japonicus]
# XP_002599330.1 hypothetical protein BRAFLDRAFT_64315 [Branchiostoma floridae]
# XP_002739929.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# EPQ04213.1 Transcription factor 20 [Myotis brandtii]
# OQV15856.1 Cytochrome P450 2U1 [Hypsibius dujardini]
# NP_001079774.1 uncharacterized protein LOC379464 [Xenopus laevis]
# KTF72511.1 hypothetical protein cypCar_00036885 [Cyprinus carpio]
# CDQ61137.1 unnamed protein product [Oncorhynchus mykiss]
# XP_006813064.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# XP_022081995.1 cytochrome P450 2U1-like [Acanthaster planci]
# BAB55227.1 unnamed protein product [Homo sapiens]
# XP_009049745.1 hypothetical protein LOTGIDRAFT_201270 [Lottia gigantea]
# XP_002119562.1 PREDICTED: cytochrome P450 2U1 isoform X1 [Ciona intestinalis]
# BAE28887.1 unnamed protein product, partial [Mus musculus]
# AAA52156.1 cytochrome P450IIF1 [Homo sapiens]
# AQM55163.1 cytochrome P450 [Eremias argus]
# EDK97564.1 hypothetical protein F730023N20, isoform CRA_b [Mus musculus]
# PIO33475.1 hypothetical protein AB205_0042540 [Rana catesbeiana]
# NP_001124095.1 uncharacterized protein LOC100170784 [Danio rerio]
# XP_019727008.1 PREDICTED: uncharacterized protein LOC109516706 [Hippocampus comes]
# AAX08055.1 cytochrome P450 [Danio rerio]
# ARN17925.1 cytochrome P450-2 [Cephus cinctus]
# GAV05746.1 hypothetical protein RvY_15827 [Ramazzottius varieornatus]
# KPP60489.1 hypothetical protein Z043_121509, partial [Scleropages formosus]
# EHH59602.1 hypothetical protein EGM_09755, partial [Macaca fascicularis]
# OCA25679.1 hypothetical protein XENTR_v90020987mg [Xenopus tropicalis]
# BAD02925.1 cytochrome P450, partial [Cavia porcellus]
# OQV22988.1 Cytochrome P450 2U1 [Hypsibius dujardini]
# CAJ31114.1 cytochrome P450 [Spodoptera littoralis]
# XP_011439331.1 PREDICTED: cytochrome P450 2U1 [Crassostrea gigas]
# ETN60006.1 cytochrome P450 [Anopheles darlingi]
# OPJ78943.1 carboxypeptidase N subunit 2 [Patagioenas fasciata monilis]
# XP_022076661.1 uncharacterized protein LOC110970662 [Acanthochromis polyacanthus]
# AAA41065.1 cytochrome P450 PB1, partial [Rattus norvegicus]
# AAD54014.1 cytochrome P450 [Fundulus heteroclitus]
# PCG68521.1 hypothetical protein B5V51_5141 [Heliothis virescens]
# XP_013408661.1 PREDICTED: cytochrome P450 2U1-like [Lingula anatina]
# KFB43110.1 cytochrome P450 [Anopheles sinensis]
# EDM07988.1 rCG53651, isoform CRA_a [Rattus norvegicus]
# XP_013420531.1 PREDICTED: cytochrome P450 2U1-like isoform X3 [Lingula anatina]
# XP_017202860.1 PREDICTED: cytochrome P450 2U1 isoform X3 [Oryctolagus cuniculus]
# CDQ61740.1 unnamed protein product [Oncorhynchus mykiss]
# OXB81986.1 hypothetical protein H355_004069 [Colinus virginianus]
# PIO33931.1 hypothetical protein AB205_0064460 [Rana catesbeiana]
# AGN04279.1 cytochrome P450 [Oryzias melastigma]
# AAH60406.1 MGC68590 protein [Xenopus laevis]
# KPM09295.1 cytochrome P450-like protein 20 [Sarcoptes scabiei]
# KTG41404.1 hypothetical protein cypCar_00000835 [Cyprinus carpio]
# XP_022093163.1 cytochrome P450 2U1-like [Acanthaster planci]
# XP_012941496.1 PREDICTED: cytochrome P450 2U1-like [Aplysia californica]
# ETE57122.1 Cytochrome protein, partial [Ophiophagus hannah]
# AGN04281.1 cytochrome P450 [Oryzias melastigma]
# XP_002427451.1 cytochrome P-450, putative [Pediculus humanus corporis]
# OXB55490.1 hypothetical protein ASZ78_016461 [Callipepla squamata]
# XP_002735731.1 PREDICTED: cytochrome P450 2U1-like [Saccoglossus kowalevskii]
# OCA27894.1 hypothetical protein XENTR_v90017683mg [Xenopus tropicalis]
# OQV23040.1 Cytochrome P450 2U1 [Hypsibius dujardini]
# XP_013065833.1 PREDICTED: cytochrome P450 2U1-like [Biomphalaria glabrata]
# CDQ68588.1 unnamed protein product [Oncorhynchus mykiss]
# ACN93795.1 cytochrome p450 [Reticulitermes flavipes]
# ARA91622.1 cytochrome P450 monooxygenase [Pieris rapae]
# KTF73478.1 hypothetical protein cypCar_00039116 [Cyprinus carpio]
# AEO50743.1 cytochrome P450 II f2-like protein II [Biomphalaria glabrata]
# ANJ46825.1 17 alpha hydroxylase and 17-20 lyase [Rachycentron canadum]
# XP_013774212.1 cytochrome P450 2U1-like [Limulus polyphemus]
# OXB65445.1 hypothetical protein ASZ78_005072 [Callipepla squamata]
# OCA35970.1 hypothetical protein XENTR_v900152883mg, partial [Xenopus tropicalis]
# OXB80279.1 hypothetical protein H355_013677 [Colinus virginianus]
# XP_023372804.1 cytochrome P450 2U1 isoform X2 [Otolemur garnettii]
# EDM07989.1 rCG53651, isoform CRA_b [Rattus norvegicus]
# CDQ61105.1 unnamed protein product [Oncorhynchus mykiss]
# AAR87724.1 cytochrome P4501C2 [Cyprinus carpio]
# KRT82761.1 cytochrome P450 [Oryctes borbonicus]
# XP_016807465.1 PREDICTED: cytochrome P450 2U1 isoform X3 [Pan troglodytes]
# XP_013408665.1 PREDICTED: cytochrome P450 2U1-like [Lingula anatina]
# XP_002011724.1 uncharacterized protein Dmoj_GI10931 [Drosophila mojavensis]
# ...
# WP_101177068.1 cytochrome P450 [Bacillus nealsonii]
# WP_045936959.1 MULTISPECIES: cytochrome P450 [Streptomyces]
# KOU56512.1 cytochrome P450 [Streptomyces sp. IGB124]
# KOU93479.1 cytochrome P450 [Streptomyces sp. XY593]
# WP_053687557.1 MULTISPECIES: cytochrome P450 [Streptomyces]
# KOU88445.1 cytochrome P450 [Streptomyces sp. XY66]
# WP_053677541.1 cytochrome P450 [Streptomyces sp. XY66]
# WP_053628873.1 MULTISPECIES: cytochrome P450 [Streptomyces]
# OJV12892.1 cytochrome P450 [Dyadobacter sp. 50-39]
# WP_088889625.1 cytochrome P450 [Leptolyngbya ohadii]
# KOT49848.1 cytochrome P450 [Streptomyces rimosus subsp. rimosus]
# XP_009495956.1 hypothetical protein H696_03822 [Fonticula alba]
# XP_020441368.1 1,25-dihydroxyvitamin D(3) 24-hydroxylase, mitochondrial [Monopterus albus]
# WP_017742491.1 cytochrome P450 [Scytonema hofmannii]
# WP_030643016.1 cytochrome P450 [Streptomyces rimosus]
# PAV63544.1 hypothetical protein WR25_07696 [Diploscapter pachys]
# WP_020721947.1 cytochrome P450 [Acidobacteriaceae bacterium KBS 96]
# WP_013560294.1 cytochrome P450 [Anaerolinea thermophila]
# OYY54924.1 cytochrome P450 [Halothiobacillus sp. 28-55-5]
# EHH24176.1 hypothetical protein EGK_07787, partial [Macaca mulatta]
# NP_001233600.1 cytochrome P450 1D1 [Macaca mulatta]
# EHH57462.1 hypothetical protein EGM_07089, partial [Macaca fascicularis]
# AKH03499.1 cytochrome P450 3029B1 [Paracyclopina nana]
# EFX89972.1 hypothetical protein DAPPUDRAFT_300053 [Daphnia pulex]
# OPJ70063.1 hypothetical protein AV530_019306 [Patagioenas fasciata monilis]
# EHH19339.1 hypothetical protein EGK_20024 [Macaca mulatta]
# PAA54355.1 hypothetical protein BOX15_Mlig034435g2 [Macrostomum lignano]
# GAV00008.1 hypothetical protein RvY_10925-1 [Ramazzottius varieornatus]
# AAA31431.1 cytochrome P-450, partial [Oryctolagus cuniculus]
# ETE72391.1 Cytochrome protein, partial [Ophiophagus hannah]
# GAV00057.1 hypothetical protein RvY_10962-2 [Ramazzottius varieornatus]
# NP_503615.1 CYtochrome P450 family [Caenorhabditis elegans]
# OXU31223.1 hypothetical protein TSAR_014757 [Trichomalopsis sarcophagae]
# OZF85200.1 hypothetical protein FL82_14680, partial [Caenorhabditis remanei]
# XP_003116461.1 hypothetical protein CRE_09179 [Caenorhabditis remanei]
# GAV00056.1 hypothetical protein RvY_10962-1 [Ramazzottius varieornatus]
# OWK07539.1 hypothetical protein Celaphus_00008582, partial [Cervus elaphus hippelaphus]
# EAT46796.1 AAEL002071-PA [Aedes aegypti]
# ETN65092.1 cytochrome P450 [Anopheles darlingi]
# XP_009051044.1 hypothetical protein LOTGIDRAFT_231412 [Lottia gigantea]
# XP_015906524.1 uncharacterized protein LOC107438707 [Parasteatoda tepidariorum]
# ATB55046.1 cytochrome P450 305E1 [Aphis gossypii]
# XP_002020904.1 GL16299 [Drosophila persimilis]
# XP_001357133.2 uncharacterized protein Dpse_GA17998 [Drosophila pseudoobscura pseudoobscura]
# XP_002410454.1 cytochrome P450, putative, partial [Ixodes scapularis]
# XP_001954078.1 uncharacterized protein Dana_GF16922, isoform A [Drosophila ananassae]
# XP_017151021.1 PREDICTED: uncharacterized protein LOC108161311 [Drosophila miranda]
# PAA53688.1 hypothetical protein BOX15_Mlig012961g3 [Macrostomum lignano]
# PAA83765.1 hypothetical protein BOX15_Mlig012961g4 [Macrostomum lignano]
# XP_002051756.1 uncharacterized protein Dvir_GJ10597 [Drosophila virilis]
# XP_001988928.1 GH10311 [Drosophila grimshawi]
# KHJ49454.1 unspecific monooxygenase [Trichuris suis]
# KYQ50759.1 hypothetical protein ALC60_10155 [Trachymyrmex zeteki]
# GAV00058.1 hypothetical protein RvY_10962-3 [Ramazzottius varieornatus]
# ACO87994.1 P450 [Nilaparvata lugens]
# KFD57765.1 hypothetical protein M513_01435 [Trichuris suis]
# WP_063367342.1 cytochrome P450 [Pseudoalteromonas luteoviolacea]
# KJH47394.1 unspecific monooxygenase [Dictyocaulus viviparus]
# BAM73843.1 cytochrome P450, partial [Bombyx mori]
# BAA85387.1 cytochrome P450 XL-304 [Xenopus laevis]
# NP_507688.2 CYtochrome P450 family [Caenorhabditis elegans]
# WP_078521431.1 cytochrome P450 [Streptomyces sp. CNT372]
# WP_051084952.1 cytochrome P450 [Kribbella catacumbae]
# WP_088643804.1 cytochrome P450 [Micromonospora wenchangensis]
# XP_002115670.1 hypothetical protein TRIADDRAFT_59598 [Trichoplax adhaerens]
# WP_014433316.1 cytochrome P450 [Caldilinea aerophila]
# CEM01422.1 unnamed protein product [Vitrella brassicaformis CCMP3155]
# WP_081237695.1 cytochrome P450 [Streptomyces viridosporus]
# XP_006129468.1 PREDICTED: 1,25-dihydroxyvitamin D(3) 24-hydroxylase, mitochondrial isoform X1 [Pelodiscus sinensis]
# WP_007569844.1 cytochrome P450 [Patulibacter medicamentivorans]
# ADZ25011.1 cytochrome P450 hydroxylase [Sorangium cellulosum]
# WP_044013331.1 cytochrome P450 [Hymenobacter sp. APR13]
# GAU97763.1 hypothetical protein RvY_09002 [Ramazzottius varieornatus]
# CEM01481.1 unnamed protein product [Vitrella brassicaformis CCMP3155]
# CEO96519.1 hypothetical protein PBRA_005128 [Plasmodiophora brassicae]
# WP_098514381.1 cytochrome P450 [Amycolatopsis sulphurea]
# WP_078969849.1 cytochrome P450 [Streptomyces natalensis]
# PFG39747.1 cytochrome P450 [Georgenia soli]
# XP_012395157.1 1,25-dihydroxyvitamin D(3) 24-hydroxylase, mitochondrial isoform X1 [Sarcophilus harrisii]
# WP_098483793.1 cytochrome P450 [Georgenia soli]
# WP_046779537.1 cytochrome P450 [Streptomyces yangpuensis]
# PIO25699.1 hypothetical protein AB205_0161630, partial [Rana catesbeiana]
# WP_088570130.1 cytochrome P450 [Thermoflexus hugenholtzii]
# WP_089942846.1 cytochrome P450 [Candidatus Entotheonella palauensis]
# ABQ59243.1 CYP97C3 [Chlamydomonas reinhardtii]
# WP_056524819.1 cytochrome P450 [Bacillus sp. Leaf13]
# WP_076477043.1 cytochrome P450 [Burkholderia ubonensis]
# WP_098176892.1 cytochrome P450 [Bacillus butanolivorans]
# WP_059651203.1 cytochrome P450 [Burkholderia ubonensis]
# APW83733.1 cytochrome P450 carotenoid hydroxylase 97A [Dunaliella salina]
# WP_084436157.1 cytochrome P450 [Rhodococcus kunmingensis]
# WP_086823002.1 cytochrome P450 [Allokutzneria sp. NRRL B-24872]
# WP_054413593.1 cytochrome P450 [Hymenobacter sp. DG25A]
# AHJ96794.1 hypothetical protein Hsw_1199 [Hymenobacter swuensis DY53]
# WP_079046802.1 cytochrome P450 [Streptomyces kanasensis]
# XP_002400108.1 cytochrome P450, putative [Ixodes scapularis]
# WP_081768301.1 cytochrome P450 [Hymenobacter swuensis]
# KWN68283.1 hypothetical protein WM24_09395 [Burkholderia ubonensis]
# OLD83850.1 hypothetical protein AUG54_01540 [Ktedonobacter sp. 13_1_20CM_4_53_7]
# WP_060215534.1 cytochrome P450 [Burkholderia ubonensis]
# WP_010684892.1 cytochrome P450 [Methylobacterium mesophilicum]
# WP_060117030.1 cytochrome P450 [Burkholderia ubonensis]
# WP_063906724.1 cytochrome P450 [Burkholderia ubonensis]
# OFW22529.1 cytochrome P450 [Acidobacteria bacterium RIFCSPLOWO2_02_FULL_65_29]
# WP_037902129.1 cytochrome P450 [Streptomyces sp. NRRL S-350]
# XP_019529120.1 PREDICTED: uncharacterized protein LOC109401093 [Aedes albopictus]
# KVU01922.1 hypothetical protein WK62_17635 [Burkholderia ubonensis]
# KVT84431.1 hypothetical protein WK59_13310 [Burkholderia ubonensis]
# XP_002428239.1 cytochrome P-450, putative [Pediculus humanus corporis]
# WP_098371679.1 cytochrome P450 [Bacillus sp. AFS017274]
# WP_086000891.1 cytochrome P450 [Plesiocystis pacifica]
# WP_063900291.1 cytochrome P450 [Burkholderia ubonensis]
# WP_063803338.1 cytochrome P450 [Burkholderia ubonensis]
# WP_056708823.1 cytochrome P450 [Bosea sp. Leaf344]
# WP_037605760.1 cytochrome P450 [Streptacidiphilus rugosus]
# KVT96149.1 hypothetical protein WK60_09060 [Burkholderia ubonensis]
# XP_009053700.1 hypothetical protein LOTGIDRAFT_239424 [Lottia gigantea]
# ODS79959.1 cytochrome P450 [Acidovorax sp. SCN 65-28]
# KVD40564.1 hypothetical protein WI84_08095 [Burkholderia ubonensis]
# WP_043382962.1 MULTISPECIES: cytochrome P450 [Methylobacterium]
# PFX33651.1 Cholesterol 24-hydroxylase [Stylophora pistillata]
# WP_015129620.1 cytochrome P450 [Calothrix sp. PCC 7507]
# AMQ49206.1 cytochrome P450, partial [Penaeus monodon]
# WP_075738717.1 cytochrome P450 [Streptomyces acidiscabies]
# WP_051976078.1 MULTISPECIES: cytochrome P450 [Bacteria]
# WP_083769505.1 cytochrome P450 [[Bacillus] selenitireducens]
# WP_063801512.1 cytochrome P450 [Burkholderia ubonensis]
# WP_030850542.1 cytochrome P450 [Streptomyces sp. NRRL S-475]
# WP_078897370.1 cytochrome P450 [Streptomyces rimosus]
# WP_050504043.1 cytochrome P450 [Streptomyces rimosus]
# WP_052517686.1 cytochrome P450 [Archangium violaceum]
# WP_063894381.1 cytochrome P450 [Burkholderia ubonensis]
# WP_091785205.1 cytochrome P450 [Methylobacterium sp. UNC378MF]
# OWR52238.1 cytochrome P450 [Danaus plexippus plexippus]
# WP_084770405.1 cytochrome P450 [Streptomyces sp. MOE7]
# AGT51299.1 cytochrome P450 [Aedes albopictus]
# KXJ71197.1 hypothetical protein RP20_CCG021259 [Aedes albopictus]
# SDA28400.1 Cytochrome P450 [Methylobacterium sp. UNC378MF]
# XP_310940.5 AGAP000194-PA [Anopheles gambiae str. PEST]
# KDD76660.1 cytochrome P450, partial [Helicosporidium sp. ATCC 50920]
# OXA41089.1 Transposon Ty3-G Gag-Pol polyprotein [Folsomia candida]
# XP_022798477.1 cholesterol 24-hydroxylase-like [Stylophora pistillata]
# WP_075381090.1 cytochrome P450 [Methylobacterium phyllosphaerae]
# WP_078983962.1 cytochrome P450 [Streptomyces lydicus]
# OWA53458.1 Cytochrome P450 10 [Hypsibius dujardini]
# WP_078971249.1 cytochrome P450 [Streptomyces chattanoogensis]
# WP_030289433.1 MULTISPECIES: cytochrome P450 [Streptomycetaceae]
# XP_002115668.1 hypothetical protein TRIADDRAFT_29528 [Trichoplax adhaerens]
# WP_072394910.1 cytochrome P450 [Hyphomicrobium sp. CS1GBMeth3]
# XP_022342408.1 1,25-dihydroxyvitamin D(3) 24-hydroxylase, mitochondrial-like [Crassostrea virginica]
# AFM82473.1 cytochrome P450 [Palaemon carinicauda]
# CEM05688.1 unnamed protein product [Vitrella brassicaformis CCMP3155]
# WP_030416236.1 cytochrome P450 [Streptomyces sp. NRRL S-1448]
# WP_052341429.1 cytochrome P450 [Salinarimonas rosea]
# XP_008606797.1 hypothetical protein SDRG_02963 [Saprolegnia diclina VS20]
# WP_030635288.1 cytochrome P450 [Streptomyces rimosus]
# WP_044512816.1 cytochrome P450 [Hymenobacter sp. DG25B]
# WP_092864923.1 cytochrome P450 [Hyphomicrobium facile]
# XP_008407147.1 PREDICTED: 1,25-dihydroxyvitamin D(3) 24-hydroxylase, mitochondrial [Poecilia reticulata]
# WP_052412445.1 cytochrome P450 [Streptomyces luteus]
# WP_007166144.1 cytochrome P450 [Erythrobacter sp. NAP1]
# WP_068591250.1 cytochrome P450 [Ulvibacter sp. LPB0005]
# AGN04316.1 cytochrome P450 [Oryzias melastigma]
# WP_098698506.1 cytochrome P450 [Nocardia terpenica]
# WP_092888440.1 cytochrome P450 [Actinopolymorpha cephalotaxi]
# KZC02540.1 putative bifunctional P-450/NADPH-P450 reductase 2 [Methylobacterium radiotolerans]
# WP_079436403.1 cytochrome P450 [Zoogloea sp. LCSB751]
# WP_012824348.1 cytochrome P450 [Halothiobacillus neapolitanus]
# WP_020375556.1 cytochrome P450 [Sulfobacillus thermosulfidooxidans]
# KYN38874.1 hypothetical protein ALC56_06873 [Trachymyrmex septentrionalis]
# AKH03509.1 cytochrome P450 3075A3 [Paracyclopina nana]
# WP_017308210.1 cytochrome P450 [Fischerella sp. PCC 9339]
# OZF77113.1 hypothetical protein FL82_19372, partial [Caenorhabditis remanei]
# OZF85201.1 hypothetical protein FL82_14681, partial [Caenorhabditis remanei]
# AKH03520.1 cytochrome P450 3130A1 [Paracyclopina nana]
# EDM02788.1 rCG62402, isoform CRA_b [Rattus norvegicus]
# NP_504988.1 CYtochrome P450 family [Caenorhabditis elegans]
# WP_017308209.1 cytochrome P450 [Fischerella sp. PCC 9339]
# XP_319235.4 AGAP010077-PA [Anopheles gambiae str. PEST]
# PAV74019.1 hypothetical protein WR25_00485 [Diploscapter pachys]
# PDM80038.1 cytochrome P450 [Pristionchus pacificus]
# CAP22548.2 Protein CBR-CYP-33C12 [Caenorhabditis briggsae]
# OZG03687.1 hypothetical protein FL82_06281, partial [Caenorhabditis remanei]
# EGT49929.1 hypothetical protein CAEBREN_31050 [Caenorhabditis brenneri]
# OZG22790.1 hypothetical protein FL83_02797, partial [Caenorhabditis latens]
# OZG12462.1 hypothetical protein FL83_12929, partial [Caenorhabditis latens]
# PDM79703.1 cytochrome P450 [Pristionchus pacificus]
# OZF85225.1 hypothetical protein FL82_14762, partial [Caenorhabditis remanei]
# XP_003116384.1 hypothetical protein CRE_09125 [Caenorhabditis remanei]
# ODM90831.1 Farnesoate epoxidase [Orchesella cincta]
# XP_012754385.1 hypothetical protein SAMD00019534_054400 [Acytostelium subglobosum LB1]
# XP_020428241.1 cytochrome P450 family protein [Polysphondylium pallidum PN500]
# OXA50570.1 Farnesoate epoxidase [Folsomia candida]
# OIK11467.1 cytochrome P450 [Bacillus sp. MUM 13]
# WP_012234495.1 cytochrome P450 [Sorangium cellulosum]
# WP_083392147.1 cytochrome P450 [Bacillus sp. MUM 13]
# OYT88008.1 cytochrome P450 [Burkholderiales bacterium PBB6]
# CDQ56620.1 unnamed protein product [Oncorhynchus mykiss]
# WP_013861376.1 cytochrome P450 [Microlunatus phosphovorus]
# WP_046423668.1 cytochrome P450 [Streptomyces malaysiense]
# WP_100204020.1 cytochrome P450 [Streptomyces sp. TRM SA0054]
# WP_096557773.1 cytochrome P450 [Nostoc sp. NIES-4103]
# WP_015152944.1 cytochrome P450 [Chroococcidiopsis thermalis]
# WP_093492919.1 cytochrome P450 [Streptomyces sp. 2112.3]
# WP_088796925.1 MULTISPECIES: cytochrome P450 [Streptomyces]
# WP_092893654.1 cytochrome P450 [Halopelagius inordinatus]
# WP_084195440.1 cytochrome P450 [Streptosporangium amethystogenes]
# KRT83099.1 cytochrome P450 [Oryctes borbonicus]
# WP_020734243.1 cytochrome P450 [Sorangium cellulosum]
# BAG60675.1 unnamed protein product [Homo sapiens]
# WP_028668107.1 cytochrome P450 [Runella zeae]
# WP_067524722.1 cytochrome P450 [Nocardia uniformis]
# WP_020536297.1 cytochrome P450 [Lewinella cohaerens]
# WP_093722010.1 cytochrome P450 [Streptomyces sp. DI166]
# WP_075137835.1 cytochrome P450 [Actinophytocola xinjiangensis]
# SBT92473.1 Cytochrome P450 [Streptomyces sp. DI166]
# SEC37396.1 Cytochrome P450 [Streptomyces sp. 1222.5]
# WP_093475620.1 MULTISPECIES: cytochrome P450 [Streptomyces]
# SIR73054.1 Cytochrome P450 [Microbispora rosea]
# WP_053613969.1 cytochrome P450 [Streptomyces sp. XY533]
# KOU11919.1 cytochrome P450 [Streptomyces sp. WM6349]
# WP_051734463.1 MULTISPECIES: cytochrome P450 [Streptomyces]
# KOU92273.1 cytochrome P450 [Streptomyces sp. XY533]
# WP_093697167.1 cytochrome P450 [Streptomyces sp. 2231.1]
# AKF11647.1 cytochrome P450 [Sandaracinus amylolyticus]
# WP_042157238.1 cytochrome P450 [Streptomyces sp. NBRC 110027]
# APR75541.1 cytochrome P450 [Minicystis rosea]
# WP_092904002.1 cytochrome P450 [Halostagnicola kamekurae]
# WP_024755714.1 cytochrome P450 [Streptomyces exfoliatus]
# PFG48600.1 pentalenene oxygenase [Amycolatopsis sulphurea]
# WP_078860546.1 cytochrome P450 [Streptomyces rubellomurinus]
# WP_083744424.1 cytochrome P450 [Microbispora rosea]
# WP_085927043.1 cytochrome P450 [Streptomyces platensis]
# WP_069758203.1 cytochrome P450 [Streptomyces sp. LUP47B]
# WP_052857253.1 cytochrome P450 [Streptomyces celluloflavus]
# KFE69311.1 cytochrome P450 [Hyalangium minutum]
# WP_091640844.1 cytochrome P450 [Micromonospora pallida]
# WP_030661792.1 cytochrome P450 [Streptomyces rimosus]
# WP_056555123.1 MULTISPECIES: cytochrome P450 [Streptomyces]
# WP_046280964.1 cytochrome P450 [Limnoraphis robusta]
# WP_051104019.1 cytochrome P450 [Streptomyces sp. FxanaC1]
# WP_009755628.1 cytochrome P450 [Nitratireductor indicus]
# WP_088984491.1 cytochrome P450 [Micromonospora echinospora]
# WP_094790831.1 cytochrome P450 [Streptomyces kasugaensis]
# OAI42992.1 cytochrome P450 [Verrucomicrobia bacterium SCGC AG-212-E04]
# WP_053694785.1 cytochrome P450 [Streptomyces sp. NRRL F-5755]
# WP_039896954.1 cytochrome P450 [Lyngbya sp. PCC 8106]
# WP_054492799.1 cytochrome P450 [Ardenticatena maritima]
# WP_030639930.1 cytochrome P450 [Streptomyces rimosus]
# EAW34775.1 cytochrome P450 hydroxylase [Lyngbya sp. PCC 8106]
# WP_048645456.1 cytochrome P450 [Nitratireductor soli]
# WP_067353456.1 cytochrome P450 [Streptomyces noursei]
# WP_042807854.1 cytochrome P450 [Streptomyces rimosus]
# WP_073768017.1 cytochrome P450 [Streptomyces sp. CB02923]
# XP_013906761.1 hypothetical protein MNEG_0211 [Monoraphidium neglectum]
# WP_003982152.1 MULTISPECIES: cytochrome P450 [Streptomycetaceae]
# WP_078875955.1 cytochrome P450 [Streptomyces sp. 769]
# KXK15108.1 cytochrome P450 [Chloroflexi bacterium OLB14]
# WP_030021430.1 cytochrome P450 [Streptomyces monomycini]
# WP_014179766.1 MULTISPECIES: cytochrome P450 [Streptomyces]

# %%
species_names = get_species_names(species_counts, min=1)
for name in species_names:
    print (name)

# %%
species_counts = build_species_count(records=test_records)

# %% [markdown]
# ### Adding terms to the `header_terms` variable
# The following section makes it easy to add in terms to the `header_terms` variable and to save these files for later use.
#
# Let's first print out the terms in our variable and the length of it. As you add to the list you can always come back and rerun this cell to peek inside the `header_terms` variable

# %%
print (header_terms)
print (len(header_terms))

# %% [markdown]
# The first thing we might be interested in doing is to print out the header information of the sequences we currently have.

# %%
for record in filtered_records:
    print (filtered_records[record].description)

# %% [markdown]
# The cell below will add items to our `header_terms` variable. Hit run on the cell and you'll see an input box - simply add words seperated by a space that you want to add.

# %%
add = widgets.Text()
display(add)

def handle_submit(sender):
    for item in add.value.split():
        header_terms.append(item)
    print (header_terms)
add.on_submit(handle_submit)

# %% [markdown]
# And then we can also remove

# %%
remove = widgets.Text()
display(remove)

def handle_submit(sender):
    for item in remove.value.split():
        header_terms.remove(item)
    print (header_terms)

remove.on_submit(handle_submit)

# %% [markdown]
# Below is that cell that lets us check all the words in `header_terms` so far.

# %%
print (header_terms)
print (len(header_terms))

# %% [markdown]
# Have a play around with adding and removing words to the `header_terms` list and then the following cells illustrate how it can be used.
#
# Make the `header_terms` list contain just the terms "2B4" and "2B4-like" and then we'll create a new record called `only_2B4_records`

# %%
only_2B4_records = subset_records(*header_terms, records=full_record, mode='include')
for record in only_2B4_records:
    print (only_2B4_records[record].description)

# %% [markdown]
# ### Saving and loading the header terms variable

# %%
utilities.saveHeaderTerms(header_terms, "files/headerterms.txt")

# %%
header_terms = utilities.loadHeaderTerms("files/headerterms.txt")

# %% [markdown]
# ### Subsetting record files using regular expressions
# Typing all of the particular items we want to include or exclude can be time-consuming, and often we want to include or exclude all of the members of a family. So we can use regular expressions in `subset_records_with_regex` and only supply the first part of the family name and have it automatically match to all headers that contain text starting with that first part.
#
# For example - excluding "2J" would exclude "2J6", "2J2", and "2J2-like" (as well as others)

# %% [markdown]
# # Evaluating how many hits per species
#
# `build_species_count` builds a dictionary which has the set of unique species as its keys and a list of the sequence IDs that belong to each unique species as its . So we can use it to easily see how many unique species we have and which species are over represented.

# %%
species_counts = build_species_count(records=full_record)
print("There are %s unique species in our dataset." % (len(species_counts)))

# %% [markdown]
# ### Plotting the frequency of proteins per species
# `plot_record_number` is a function that plots the numbers of IDs per species. We can set a minimum number of IDs that a species must have in order to be plotted.

# %%
plotthis = plot_record_number(species_counts, "Bar", min=3)
py.iplot(plotthis, filename='inline_bar')

# %%
plotthis = plot_record_number(species_counts, "Bar", min=2)
py.iplot(plotthis, filename='inline_bar')

# %%
plotthis = plot_record_number(species_counts, "Bar", min=5)
py.iplot(plotthis, filename='inline_bar')

# %% [markdown]
# #### We can also just extract the names using `get_species_name`, which also accepts a minimum number of IDs required and can print out the number of counts per each species

# %%
species_names_with_counts = get_species_names(species_counts, min=3, counts=True)
for name in species_names_with_counts:
    print (name)

# %% [markdown]
# ### Counting the total number of sequences with multiple hits
# `count_ids` is a function that counts the total number of sequences in a species count dictionary, not just the number of unique species.
#
# As before, it can also take a minimum number of IDs required

# %%
min_num = 5
print ("There are %s total sequences in our filtered dataset." % (count_ids(species_counts)))
print ("There are %s total sequences in our filtered dataset that have %d or more IDs per species." % (count_ids(species_counts, min=min_num), min_num))

# %% [markdown]
# # Generating datasets containing information about species with multiple hits
# For each species that has more than the given number of hits, we create
# 1. A FASTA file of the protein sequences from that species
# 2. An alignment of the protein sequences
# 3. An information file telling use where in the genome the protein maps to
# 4. A visual diagram of the genome mapping the proteins to the genome

# %%
def generate_multiple_hit_data(species_names, species_counts, full_record, file_path):
    id_dict = {}
#     for name in species_names:
#         seqs = map_species_to_records(species_counts[name], full_record)
#         write_fasta(seqs, file_path + name + " sequences")
#         alignmentFile = alignment.alignWithMAFFT(file_path + name + " sequences")
#         alignment.writeAlignment(alignmentFile, file_path + name + ".aln", "fasta")
        

    check_genomic_location(species_counts, min=1, file_path=file_path +" gene locations ")
    check_genomic_location(species_counts, min=1, visualise="linear")


species_names = get_species_names(species_counts, min=1)
generate_multiple_hit_data(species_names, species_counts, full_record, "files/multiple_hits/")

# %% [markdown]
# Or we could just use parts of this function. The cell below will just print out the locations of the proteins in the genome. We could save this to disk by providing an argument to the `file_path` variable or visualise it by providing either 'linear' or 'circular' to the `visualise` variable.

# %%
check_genomic_location(species_counts, min=5)

# %% [markdown]
# # Saving the records to FASTA files
# Because `filtered_records` just contains the species name and IDs of these species, we need to map these IDs back to their full records. We can use the function `map_ids_to_records` which allows for us to select all the records in `filtered_ids` or just the unique species.

# %%
filtered_records = map_ids_to_records(species_counts, full_record)
filtered_records_unique = map_ids_to_records(species_counts, full_record, unique=True)

# Check that the numbers are correct
print (len(filtered_records))
print (len(filtered_records_unique))

# %% [markdown]
# And now we can save these records to a new FASTA file using `write_fasta`

# %%
write_fasta(filtered_records, "files/2U1_BLAST_smaller_records.fasta")
# write_fasta(filtered_records_unique, "files/2U1_BLAST_filtered_records_unique.fasta")

# %% [markdown]
# We can also use the function `map_species_to_records` to just map a particular species to a FASTA file.

# %%
priapulus_caudatus = map_species_to_records(species_counts['Priapulus caudatus'], full_record)
write_fasta(priapulus_caudatus, "files/priapulus_caudatus.fasta")
